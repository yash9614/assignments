# %% [markdown]
# ![image.png](attachment:f2203747-827a-47f7-9bd6-9f078726536a.png)

# %%
'''1. Given an array, check if it contains any duplicates or not.
arr = [1, 2, 4, 2, 5, 9]
Output = True
'''

def contains_duplicate(arr):
    seen = set()
    for num in arr:
        if num in seen:
            return True
        seen.add(num)
    return False

# %%
# check if an array contains duplicate elements or not:

'''
2. Given an array and an integer k, rotate the array to the right by k steps.
arr = [1, 2, 3, 4, 5, 6, 7] k = 3
Output = [5, 6, 7, 1, 2, 3, 4]
'''

def rotate_array(arr, k):
    n = len(arr)
    k = k % n
    arr.reverse()
    arr[:k] = reversed(arr[:k])
    #reverse the remaining elements:
    arr[k:] = reverse(arr[k:])

# %%
'''
3. Reverse the given array in-place, means without using any extra data structure.
arr = [2, 4, 5, 7, 9, 12]
Output = [12, 9, 7, 5, 4, 2]

'''

# reverse the array in place without using any extra data structure:

def reverse_array_in_place(arr):
    start = 0
    end = len(arr) - 1
    while start < end:

    #swap the elements at the start and end indices:
        arr[start], arr[end] = arr[end], arr[start]
        start += 1
        end -=1
# Out:
# 7

# %%
'''
4. Given an array of integers, find the maximum element in an array
arr = [10, 5, 20, 8, 15]
Output = 20
'''

def find_max(arr):
    if not arr:
        return None #handling empty array case
    max_element = arr[0]
    for num in arr:
        if num > max_element:
            max_element = num
    return max_element

# %%
'''
5. Given a sorted array, remove the duplicate element without using any extra data structure.
arr = [1, 1, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5]
Output = [1, 2, 3, 4, 5]

'''

def remove_duplicates(arr):
    if not arr:
        return []  # Handle empty array case
    write_index = 0

    for i in range(1, len(arr)):
        if arr[i] != arr[write_index]:
            write_index += 1
            arr[write_index] = arr[i]

    return arr[:write_index + 1]

arr = [1, 1, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5]
result = remove_duplicates(arr)
print(result)
